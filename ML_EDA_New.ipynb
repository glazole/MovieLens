# %%
import pandas as pd
import zipfile
import gzip
import numpy as np
from sqlalchemy import create_engine, String
from dbconfig import MY_DWH
host, port, user, password, database = MY_DWH()

# %% [markdown]
# ## IMDb

# %%
imdb_name = r'G:\data\name.basics.tsv.gz' # персонажи, профессии, имена
imdb_basic = r'G:\data\title.basics.tsv.gz' # фильмы, сериалы, даты выпуска, жанры
imdb_princip = r'G:\data\title.principals.tsv.gz' # участники
imdb_ratings = r'G:\data\title.ratings.tsv.gz' # рейтинг фильма, кол-во голосов

# %%
with gzip.open(imdb_name, "rt", encoding="utf-8") as f:
    df_imdb_name = pd.read_csv(f, sep="\t") 

df_imdb_name.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                     primaryProfession                           knownForTitles
# 0        actor,miscellaneous,producer  tt0072308,tt0050419,tt0027125,tt0031983
# 1  actress,soundtrack,archive_footage  tt0037382,tt0075213,tt0117057,tt0038355
# 2   actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452
# 3       actor,writer,music_department  tt0072562,tt0077975,tt0080455,tt0078723
# 4               writer,director,actor  tt0050986,tt0069467,tt0050976,tt0083922

# %%
with gzip.open(imdb_basic, "rt", encoding="utf-8") as f:
    df_imdb_basic = pd.read_csv(f, sep="\t", low_memory=False) 

df_imdb_basic.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              5  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1                     Short

# %%
unique_imdb_genres = sorted(set(genre for sublist in df_imdb_basic['genres'].dropna().str.split(',') for genre in sublist))
unique_imdb_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Film-Noir',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western',
#  '\\N']

# %% [markdown]
# Примеры фильтрации

# %%
genre_to_filter = 'Comedy'
filtered_comedy = df_imdb_basic[df_imdb_basic['genres'].str.contains(genre_to_filter, na=False)]

genres = ['Comedy', 'Romance']
romcomedy = df_imdb_basic[df_imdb_basic['genres'].str.contains('|'.join(genres), na=False)]

# %%
with gzip.open(imdb_princip, "rt", encoding="utf-8") as f:
    df_imdb_princip = pd.read_csv(f, sep="\t") 

df_imdb_princip.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0005690         producer                 producer
# 3  tt0000001         4  nm0374658  cinematographer  director of photography
# 4  tt0000002         1  nm0721526         director                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %%
with gzip.open(imdb_ratings, "rt", encoding="utf-8") as f:
    df_imdb_ratings = pd.read_csv(f, sep="\t") 

df_imdb_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2130
# 1  tt0000002            5.6       289
# 2  tt0000003            6.4      2166
# 3  tt0000004            5.3       184
# 4  tt0000005            6.2      2892

# %% [markdown]
# ## Movies Of MovieLens

# %%
movielens = pd.read_csv(r'Aggregated_Movies_Of_MovieLens.csv', dtype='object')
movielens.head()
# Out:
#   movieId   imdbId tmdbId                               title  \
# 0       1  0114709    862                    Toy Story (1995)
# 1       2  0113497   8844                      Jumanji (1995)
# 2       3  0113228  15602             Grumpier Old Men (1995)
# 3       4  0114885  31357            Waiting to Exhale (1995)
# 4       5  0113041  11862  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movielens.shape
# Out:
# (90592, 5)

# %% [markdown]
# Добавляем tt к IMDb_ID

# %%
movielens['ttimdbId'] = 'tt' + movielens['imdbId'].astype(str)
movielens.head()
# Out:
#   movieId   imdbId tmdbId                               title  \
# 0       1  0114709    862                    Toy Story (1995)
# 1       2  0113497   8844                      Jumanji (1995)
# 2       3  0113228  15602             Grumpier Old Men (1995)
# 3       4  0114885  31357            Waiting to Exhale (1995)
# 4       5  0113041  11862  Father of the Bride Part II (1995)
#
#                                         genres   ttimdbId
# 0  Adventure|Animation|Children|Comedy|Fantasy  tt0114709
# 1                   Adventure|Children|Fantasy  tt0113497
# 2                               Comedy|Romance  tt0113228
# 3                         Comedy|Drama|Romance  tt0114885
# 4                                       Comedy  tt0113041

# %% [markdown]
# ### MovieLens + IMDb

# %%
data1 = pd.merge(movielens, df_imdb_basic, left_on='ttimdbId', right_on='tconst', how='left', suffixes=('_movielens', '_imdbasic'))
data1.shape
# Out:
# (90592, 15)

# %%
data1.head()
# Out:
#   movieId   imdbId tmdbId                               title  \
# 0       1  0114709    862                    Toy Story (1995)
# 1       2  0113497   8844                      Jumanji (1995)
# 2       3  0113228  15602             Grumpier Old Men (1995)
# 3       4  0114885  31357            Waiting to Exhale (1995)
# 4       5  0113041  11862  Father of the Bride Part II (1995)
#
#                               genres_movielens   ttimdbId     tconst  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  tt0114709  tt0114709
# 1                   Adventure|Children|Fantasy  tt0113497  tt0113497
# 2                               Comedy|Romance  tt0113228  tt0113228
# 3                         Comedy|Drama|Romance  tt0114885  tt0114885
# 4                                       Comedy  tt0113041  tt0113041
#
#   titleType                 primaryTitle                originalTitle isAdult  \
# 0     movie                    Toy Story                    Toy Story       0
# 1     movie                      Jumanji                      Jumanji       0
# 2     movie             Grumpier Old Men             Grumpier Old Men       0
# 3     movie            Waiting to Exhale            Waiting to Exhale       0
# 4     movie  Father of the Bride Part II  Father of the Bride Part II       0
#
#   startYear endYear runtimeMinutes             genres_imdbasic
# 0      1995      \N             81  Adventure,Animation,Comedy
# 1      1995      \N            104     Adventure,Comedy,Family
# 2      1995      \N            101              Comedy,Romance
# 3      1995      \N            124        Comedy,Drama,Romance
# 4      1995      \N            106       Comedy,Family,Romance

# %% [markdown]
# ## TMDb - parse

# %%
tmdb_movie = pd.read_csv(r'TMDB_TOTAL.csv', sep=';', dtype={'tmdb_id': str}, low_memory=False)
tmdb_movie.shape
# Out:
# (382168, 13)

# %%
tmdb_movie.head()
# Out:
#   tmdb_id                     name  \
# 0   40605  Die Harald Schmidt Show
# 1   14424             Young Hearts
# 2   15844         A Kindred Spirit
# 3   46121         A Próxima Vítima
# 4      97      The Drew Carey Show
#
#                                             overview release_date  \
# 0  The Harald Schmidt Show is a German late night...   1995-12-05
# 1  Malhação is a Brazilian television series for ...   1995-04-24
# 2  A Kindred Spirit was a television drama series...   1995-05-15
# 3  A young law student starts to work as a detect...   1995-03-13
# 4  Drew is an assistant director of personnel in ...   1995-09-13
#
#    vote_average  vote_count  popularity original_language type  \
# 0          7.00          16    349.5288                de   tv
# 1          6.10          31    250.4493                pt   tv
# 2          0.00           0    128.6814                cn   tv
# 3          7.60          23     87.5400                pt   tv
# 4          6.55         159     85.9274                en   tv
#
#                genres                         production_companies  \
# 0             Reality                                          NaN
# 1                Soap             Cintra Produções, Estúdios Globo
# 2       Drama, Comedy                                          TVB
# 3  Soap, Crime, Drama                               Estúdios Globo
# 4              Comedy  Warner Bros. Television, Mohawk Productions
#
#    network_id network_name
# 0       163.0        SAT.1
# 1        60.0     TV Globo
# 2        48.0     TVB Jade
# 3        60.0     TV Globo
# 4         2.0          ABC

# %% [markdown]
# ### MovieLens + IMDb + (TMDb - parse)

# %%
data2 = pd.merge(data1, tmdb_movie, left_on='tmdbId', right_on='tmdb_id', how='inner', suffixes=('__imdbasic', '_tmdbparse'))
data2.shape
# Out:
# (83903, 28)

# %%
data2.head()
# Out:
#   movieId   imdbId tmdbId                     title  \
# 0       1  0114709    862          Toy Story (1995)
# 1       2  0113497   8844            Jumanji (1995)
# 2       3  0113228  15602   Grumpier Old Men (1995)
# 3       3  0113228  15602   Grumpier Old Men (1995)
# 4       4  0114885  31357  Waiting to Exhale (1995)
#
#                               genres_movielens   ttimdbId     tconst  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  tt0114709  tt0114709
# 1                   Adventure|Children|Fantasy  tt0113497  tt0113497
# 2                               Comedy|Romance  tt0113228  tt0113228
# 3                               Comedy|Romance  tt0113228  tt0113228
# 4                         Comedy|Drama|Romance  tt0114885  tt0114885
#
#   titleType       primaryTitle      originalTitle  ... release_date  \
# 0     movie          Toy Story          Toy Story  ...   1995-11-22
# 1     movie            Jumanji            Jumanji  ...   1995-12-15
# 2     movie   Grumpier Old Men   Grumpier Old Men  ...   1995-12-22
# 3     movie   Grumpier Old Men   Grumpier Old Men  ...   2007-11-10
# 4     movie  Waiting to Exhale  Waiting to Exhale  ...   1995-12-22
#
#   vote_average vote_count popularity original_language   type  \
# 0        7.968      18727    22.4492                en  movie
# 1        7.236      10707     2.9785                en  movie
# 2        6.457        394     1.2765                en  movie
# 3        0.000          0     0.7650                en     tv
# 4        6.284        171     1.2568                en  movie
#
#                                  genres  \
# 0  Animation, Adventure, Family, Comedy
# 1            Adventure, Fantasy, Family
# 2                       Romance, Comedy
# 3                                   NaN
# 4                Comedy, Drama, Romance
#
#                                 production_companies network_id  network_name
# 0                                              Pixar        NaN           NaN
# 1  TriStar Pictures, Interscope Communications, T...        NaN           NaN
# 2              Lancaster Gate, Warner Bros. Pictures        NaN           NaN
# 3                                                NaN      214.0       Sky One
# 4                                   20th Century Fox        NaN           NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ## KinoPoisk

# %%
engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{database}')
with engine.connect() as conn:
    kino = pd.read_sql_table('MOVIES_BATCH', conn, schema='public', dtype_backend='numpy_nullable')

# csv_file = r'C:\Users\admin\Downloads\kinopoisk_movies.csv'
# kino = pd.read_csv(csv_file, sep=';', low_memory=False)
kino.shape
# Out:
# (79644, 53)

# %%
kino.columns
# Out:
# Index(['status', 'movieLength', 'id', 'type', 'name', 'year', 'genres',
#        'countries', 'typeNumber', 'enName', 'ageRating', 'ratingMpaa',
#        'updatedAt', 'createdAt', 'shortDescription', 'ticketsOnSale', 'top10',
#        'top250', 'releaseYears', 'deletedAt', 'isSeries', 'seriesLength',
#        'totalSeriesLength', 'networks', 'isTmdbChecked', 'fees.world.value',
#        'fees.world.currency', 'fees.russia.value', 'fees.russia.currency',
#        'fees.usa.value', 'fees.usa.currency', 'externalId.imdb',
#        'externalId.tmdb', 'externalId.kpHD', 'rating.kp', 'rating.imdb',
#        'rating.filmCritics', 'rating.russianFilmCritics', 'rating.await',
#        'votes.kp', 'votes.imdb', 'votes.filmCritics',
#        'votes.russianFilmCritics', 'votes.await', 'premiere.world',
#        'premiere.russia', 'premiere.bluray', 'premiere.dvd', 'premiere.cinema',
#        'premiere.digital', 'budget.value', 'budget.currency', 'audience'],
#       dtype='object')

# %% [markdown]
# ### MovieLens + IMDb + (TMDb - parse) + KinoPoisk

# %%
data3 = pd.merge(data2, kino, left_on='ttimdbId', right_on='externalId.imdb', how='inner', suffixes=('_tmdbparse', '_kino'))
data3.shape
# Out:
# (76023, 81)

# %% [markdown]
# ## Для обогащения данных

# %% [markdown]
# ### Актеры Кинопоиска

# %%
with engine.connect() as conn:
    actors = pd.read_sql_table('ACTORS_BATCH', conn, schema='public', dtype_backend='numpy_nullable')
actors.head()
# Out:
#    movie_id  actor_id       actor_name     actor_en_name  \
# 0    313650    361485          Алис Ги         Alice Guy
# 1    315565   1313301   Рэйчел Джиллет     Rachel Gillet
# 2    315565    415210      Жорж Мельес    Georges Méliès
# 3    315565     65078      Шарль Перро  Charles Perrault
# 4    214609    372469  Эдвин С. Портер   Edwin S. Porter
#
#                      role  profession
# 0                    <NA>   режиссеры
# 1  Little Red Riding Hood      актеры
# 2                    <NA>   режиссеры
# 3                    <NA>  сценаристы
# 4                    <NA>   режиссеры

# %% [markdown]
# ## MovieLens Ratings

# %%
averarings = pd.read_csv('Aggregated_AverageRating_Of_MovieLens.csv')
averarings.head()
# Out:
#    movieId  averageRating  numVotes
# 0        1            3.9     76813
# 1        2            3.3     30209
# 2        3            3.2     15820
# 3        4            2.9      3028
# 4        5            3.1     15801

# %%
ratings = pd.read_csv('Aggregated_Ratings_Of_MovieLens.csv', low_memory=False)
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit='s')
ratings.head()
# Out:
#    userId  movieId  rating           timestamp
# 0       1        1     4.0 2008-11-03 17:52:19
# 1       1      110     4.0 2008-11-05 06:04:46
# 2       1      158     4.0 2008-11-03 17:31:43
# 3       1      260     4.5 2008-11-03 18:00:04
# 4       1      356     5.0 2008-11-03 17:58:39

# %%
ratings.shape
# Out:
# (101253874, 4)

# %% [markdown]
# ## MovieLens Tags

# %%
tags = pd.read_csv('Aggregated_Tags_Of_MovieLens.csv', sep=';', dtype={'movieId': str, 'userId': str})
tags['timestamp'] = pd.to_datetime(tags['timestamp'], unit='s')
tags.head()
# Out:
#   userId movieId            tag           timestamp
# 0  42915  275243   Baz Luhrmann 2023-10-12 23:56:23
# 1  42915  275243  Austin Butler 2023-10-12 23:56:21
# 2  42915  275243          1970s 2023-10-12 23:56:11
# 3  42915  275243          1960s 2023-10-12 23:56:08
# 4  42915  275243  elvis presley 2023-10-12 23:56:06

# %% [markdown]
# 1. Самые популярные теги

# %%
# top_tags = tags['tag'].value_counts().head(20)
# top_tags.plot(kind='bar', title='Top 20 tags')

# %% [markdown]
# 2. Топ тегов по фильмам

# %%
# top_tags_by_movie = tags.groupby('movieId')['tag'].apply(lambda x: x.value_counts().head(3)).reset_index(name='count')

# %% [markdown]
# 3. Какие фильмы имеют больше всего тегов

# %%
# most_tagged_movies = tags.groupby('movieId')['tag'].count().sort_values(ascending=False).head(10)

# %% [markdown]
# 4. Когда люди ставили больше всего тегов

# %%
# tags['year'] = tags['timestamp'].dt.year
# tags_per_year = tags.groupby('year')['tag'].count()
# tags_per_year.plot(title='Number of tags per year')

# %% [markdown]
# 5. Поиск по тегам: например, найти все фильмы с тегом "psychology"

# %%
# psychology_movies = tags[tags['tag'].str.contains('psychology')]

# %%
# engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{database}')
# with engine.connect() as conn:
#     kino_batch = pd.read_sql_table('MOVIES_BATCH', conn, schema='public', dtype_backend='numpy_nullable')

# # csv_file = r'C:\Users\admin\Downloads\kinopoisk_movies.csv'
# # kino_batch = pd.read_csv(csv_file, sep=';', low_memory=False)
# kino_batch.head()
